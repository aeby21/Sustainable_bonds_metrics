# %%
from sqlalchemy import create_engine
from sqlalchemy import text
import pandas as pd
import numpy as np

# %%
# Define the connection parameters (as in the Dockerfile)
user = 'postgres'
password = 'sustainable'
db = 'sustainable_bonds_db'
host = 'db'
port = '5432'

# Create the connection URL
connection_url = f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{db}'

# %%
# Create the engine
engine = create_engine(connection_url)

# %%
# insert some data into `time_series_value`
data = pd.DataFrame.from_dict(
    {
        "id": np.arange(1000) + 1,
        "value": np.random.normal(size=(1000, )),
        "date": pd.date_range("2000-01-01 00:00:00", freq="1T", periods=1000),
    }
)

print(data.head())

with engine.connect() as connection:
    data.to_sql(name="time_series_value", con=connection,
                if_exists="append", index=False)
# Out:
#    id     value                date
# 0   1 -0.892295 2000-01-01 00:00:00
# 1   2  0.634402 2000-01-01 00:01:00
# 2   3  0.129680 2000-01-01 00:02:00
# 3   4 -0.420467 2000-01-01 00:03:00
# 4   5  0.997105 2000-01-01 00:04:00

# %%
# now, let's query some rows
with engine.connect() as connection:
    # Perform database operations
    result = connection.execute(
        text(
            """
            SELECT * 
            FROM time_series_value
            WHERE date < '2000-01-02'::date
            ;
            """
        )
    )
    for row in result:
        print(row)
# Out:
# (1, datetime.datetime(2000, 1, 1, 0, 0), Decimal('-0.8922951752011471'))
# (2, datetime.datetime(2000, 1, 1, 0, 1), Decimal('0.6344021461901603'))
# (3, datetime.datetime(2000, 1, 1, 0, 2), Decimal('0.1296802018160514'))
# (4, datetime.datetime(2000, 1, 1, 0, 3), Decimal('-0.4204668363106649'))
# (5, datetime.datetime(2000, 1, 1, 0, 4), Decimal('0.9971051783791494'))
# (6, datetime.datetime(2000, 1, 1, 0, 5), Decimal('-0.08611552153734182'))
# (7, datetime.datetime(2000, 1, 1, 0, 6), Decimal('0.5639005994442386'))
# (8, datetime.datetime(2000, 1, 1, 0, 7), Decimal('0.08011964653240092'))
# (9, datetime.datetime(2000, 1, 1, 0, 8), Decimal('0.8495002692487956'))
# (10, datetime.datetime(2000, 1, 1, 0, 9), Decimal('1.192575649533084'))
# (11, datetime.datetime(2000, 1, 1, 0, 10), Decimal('-0.5040539177558941'))
# (12, datetime.datetime(2000, 1, 1, 0, 11), Decimal('-1.3896072937829291'))
# (13, datetime.datetime(2000, 1, 1, 0, 12), Decimal('0.5397303055638432'))
# (14, datetime.datetime(2000, 1, 1, 0, 13), Decimal('0.012737034389656999'))
# (15, datetime.datetime(2000, 1, 1, 0, 14), Decimal('-0.33368174520586363'))
# (16, datetime.datetime(2000, 1, 1, 0, 15), Decimal('0.618342713690536'))
# (17, datetime.datetime(2000, 1, 1, 0, 16), Decimal('1.0761381074475849'))
# (18, datetime.datetime(2000, 1, 1, 0, 17), Decimal('1.3599541671965771'))
# (19, datetime.datetime(2000, 1, 1, 0, 18), Decimal('-0.4585633248051871'))
# (20, datetime.datetime(2000, 1, 1, 0, 19), Decimal('-1.2006293022577303'))
# (21, datetime.datetime(2000, 1, 1, 0, 20), Decimal('-0.860197480558137'))
# (22, datetime.datetime(2000, 1, 1, 0, 21), Decimal('-1.2978607333536345'))
# (23, datetime.datetime(2000, 1, 1, 0, 22), Decimal('-0.2675553335471952'))
# (24, datetime.datetime(2000, 1, 1, 0, 23), Decimal('0.08520926770649019'))
# (25, datetime.datetime(2000, 1, 1, 0, 24), Decimal('1.0174600326562653'))
# (26, datetime.datetime(2000, 1, 1, 0, 25), Decimal('1.3035472435719275'))
# (27, datetime.datetime(2000, 1, 1, 0, 26), Decimal('1.8857235158460257'))
# (28, datetime.datetime(2000, 1, 1, 0, 27), Decimal('1.4276829797213606'))
# (29, datetime.datetime(2000, 1, 1, 0, 28), Decimal('-0.7377227659445197'))
# (30, datetime.datetime(2000, 1, 1, 0, 29), Decimal('2.748107162473906'))
# (31, datetime.datetime(2000, 1, 1, 0, 30), Decimal('-0.047536444576440115'))
# (32, datetime.datetime(2000, 1, 1, 0, 31), Decimal('0.4957778997078522'))
# (33, datetime.datetime(2000, 1, 1, 0, 32), Decimal('0.2615370540450234'))
# (34, datetime.datetime(2000, 1, 1, 0, 33), Decimal('0.046151175982886906'))
# (35, datetime.datetime(2000, 1, 1, 0, 34), Decimal('0.2768102526771533'))
# (36, datetime.datetime(2000, 1, 1, 0, 35), Decimal('0.5851010921385581'))
# (37, datetime.datetime(2000, 1, 1, 0, 36), Decimal('0.31350139065308763'))
# (38, datetime.datetime(2000, 1, 1, 0, 37), Decimal('-0.35720822735436875'))
# (39, datetime.datetime(2000, 1, 1, 0, 38), Decimal('-0.2061172856096724'))
# (40, datetime.datetime(2000, 1, 1, 0, 39), Decimal('-0.34567051075504884'))
# (41, datetime.datetime(2000, 1, 1, 0, 40), Decimal('-1.5232902345374253'))
# (42, datetime.datetime(2000, 1, 1, 0, 41), Decimal('-0.5261199364641256'))
# (43, datetime.datetime(2000, 1, 1, 0, 42), Decimal('0.12241428352642479'))
# (44, datetime.datetime(2000, 1, 1, 0, 43), Decimal('-0.8253486579179936'))
# (45, datetime.datetime(2000, 1, 1, 0, 44), Decimal('-0.9794125587937337'))
# (46, datetime.datetime(2000, 1, 1, 0, 45), Decimal('-1.311814023533475'))
# (47, datetime.datetime(2000, 1, 1, 0, 46), Decimal('-0.03620458036937546'))
# (48, datetime.datetime(2000, 1, 1, 0, 47), Decimal('-1.4259642792865148'))
# (49, datetime.datetime(2000, 1, 1, 0, 48), Decimal('0.8489973542200318'))
# (50, datetime.datetime(2000, 1, 1, 0, 49), Decimal('0.3883026198696954'))
# (51, datetime.datetime(2000, 1, 1, 0, 50), Decimal('0.9225556311841027'))
# (52, datetime.datetime(2000, 1, 1, 0, 51), Decimal('-1.2593645047926865'))
# (53, datetime.datetime(2000, 1, 1, 0, 52), Decimal('1.1290591404849786'))
# (54, datetime.datetime(2000, 1, 1, 0, 53), Decimal('0.5644829154993195'))
# (55, datetime.datetime(2000, 1, 1, 0, 54), Decimal('0.9798813127840785'))
# (56, datetime.datetime(2000, 1, 1, 0, 55), Decimal('0.21695205073572021'))
# (57, datetime.datetime(2000, 1, 1, 0, 56), Decimal('-1.3896470867308655'))
# (58, datetime.datetime(2000, 1, 1, 0, 57), Decimal('0.21692592165311153'))
# (59, datetime.datetime(2000, 1, 1, 0, 58), Decimal('0.5929777162328785'))
# (60, datetime.datetime(2000, 1, 1, 0, 59), Decimal('0.2338255835462893'))
# (61, datetime.datetime(2000, 1, 1, 1, 0), Decimal('0.10868728986801214'))
# (62, datetime.datetime(2000, 1, 1, 1, 1), Decimal('-0.49506603137601457'))
# (63, datetime.datetime(2000, 1, 1, 1, 2), Decimal('-1.0771774958480702'))
# (64, datetime.datetime(2000, 1, 1, 1, 3), Decimal('1.5074701157458772'))
# (65, datetime.datetime(2000, 1, 1, 1, 4), Decimal('-0.16825986683485591'))
# (66, datetime.datetime(2000, 1, 1, 1, 5), Decimal('-1.696646991478221'))
# (67, datetime.datetime(2000, 1, 1, 1, 6), Decimal('-0.4002412149764263'))
# (68, datetime.datetime(2000, 1, 1, 1, 7), Decimal('1.0457044234504698'))
# (69, datetime.datetime(2000, 1, 1, 1, 8), Decimal('0.4852069010130542'))
# (70, datetime.datetime(2000, 1, 1, 1, 9), Decimal('-0.5363334705639176'))
# (71, datetime.datetime(2000, 1, 1, 1, 10), Decimal('-1.3738903738463328'))
# (72, datetime.datetime(2000, 1, 1, 1, 11), Decimal('-1.7851691014374598'))
# (73, datetime.datetime(2000, 1, 1, 1, 12), Decimal('0.5036943865049067'))
# (74, datetime.datetime(2000, 1, 1, 1, 13), Decimal('1.0801545016043228'))
# (75, datetime.datetime(2000, 1, 1, 1, 14), Decimal('-0.13212969562522114'))
# (76, datetime.datetime(2000, 1, 1, 1, 15), Decimal('-0.6699377557533193'))
# (77, datetime.datetime(2000, 1, 1, 1, 16), Decimal('-1.885603558679795'))
# (78, datetime.datetime(2000, 1, 1, 1, 17), Decimal('1.1333386432037202'))
# (79, datetime.datetime(2000, 1, 1, 1, 18), Decimal('-1.1378025049551146'))
# (80, datetime.datetime(2000, 1, 1, 1, 19), Decimal('1.3102020081439676'))
# (81, datetime.datetime(2000, 1, 1, 1, 20), Decimal('0.04473498658280895'))
# (82, datetime.datetime(2000, 1, 1, 1, 21), Decimal('-1.3207608352186817'))
# (83, datetime.datetime(2000, 1, 1, 1, 22), Decimal('0.3858334925159911'))
# (84, datetime.datetime(2000, 1, 1, 1, 23), Decimal('-0.2927685278047796'))
# (85, datetime.datetime(2000, 1, 1, 1, 24), Decimal('-0.7719467156442206'))
# (86, datetime.datetime(2000, 1, 1, 1, 25), Decimal('-0.14621540638842948'))
# (87, datetime.datetime(2000, 1, 1, 1, 26), Decimal('0.13481655969632156'))
# (88, datetime.datetime(2000, 1, 1, 1, 27), Decimal('-0.4972497053060264'))
# (89, datetime.datetime(2000, 1, 1, 1, 28), Decimal('0.7715607054151989'))
# (90, datetime.datetime(2000, 1, 1, 1, 29), Decimal('1.366146495328295'))
# (91, datetime.datetime(2000, 1, 1, 1, 30), Decimal('-0.9125643351708088'))
# (92, datetime.datetime(2000, 1, 1, 1, 31), Decimal('0.0506769152449127'))
# (93, datetime.datetime(2000, 1, 1, 1, 32), Decimal('-0.2736535460958804'))
# (94, datetime.datetime(2000, 1, 1, 1, 33), Decimal('-0.036488492861056564'))
# (95, datetime.datetime(2000, 1, 1, 1, 34), Decimal('0.5784638577775679'))
# (96, datetime.datetime(2000, 1, 1, 1, 35), Decimal('-0.40315869613387345'))
# (97, datetime.datetime(2000, 1, 1, 1, 36), Decimal('0.4279850561627428'))
# (98, datetime.datetime(2000, 1, 1, 1, 37), Decimal('-0.8712408544305451'))
# (99, datetime.datetime(2000, 1, 1, 1, 38), Decimal('-0.37042906175131335'))
# (100, datetime.datetime(2000, 1, 1, 1, 39), Decimal('0.28259206570023765'))
# (101, datetime.datetime(2000, 1, 1, 1, 40), Decimal('-1.2368117530426812'))
# (102, datetime.datetime(2000, 1, 1, 1, 41), Decimal('-0.5236288143669877'))
# (103, datetime.datetime(2000, 1, 1, 1, 42), Decimal('0.5872964864669077'))
# (104, datetime.datetime(2000, 1, 1, 1, 43), Decimal('0.8353939200690311'))
# (105, datetime.datetime(2000, 1, 1, 1, 44), Decimal('0.08562080135050718'))
# (106, datetime.datetime(2000, 1, 1, 1, 45), Decimal('-0.733993221348025'))
# (107, datetime.datetime(2000, 1, 1, 1, 46), Decimal('-0.16682669977265832'))
# (108, datetime.datetime(2000, 1, 1, 1, 47), Decimal('-0.6183137856321754'))
# (109, datetime.datetime(2000, 1, 1, 1, 48), Decimal('-0.9437548473274072'))
# (110, datetime.datetime(2000, 1, 1, 1, 49), Decimal('0.36395698407534693'))
# (111, datetime.datetime(2000, 1, 1, 1, 50), Decimal('-1.224663600413274'))
# (112, datetime.datetime(2000, 1, 1, 1, 51), Decimal('2.3936590358339918'))
# (113, datetime.datetime(2000, 1, 1, 1, 52), Decimal('-0.13947203764793514'))
# (114, datetime.datetime(2000, 1, 1, 1, 53), Decimal('0.4525323278573047'))
# (115, datetime.datetime(2000, 1, 1, 1, 54), Decimal('-0.7159667024295873'))
# (116, datetime.datetime(2000, 1, 1, 1, 55), Decimal('-1.3649330524454133'))
# (117, datetime.datetime(2000, 1, 1, 1, 56), Decimal('0.15839169874126205'))
# (118, datetime.datetime(2000, 1, 1, 1, 57), Decimal('-0.6448608820373732'))
# (119, datetime.datetime(2000, 1, 1, 1, 58), Decimal('-2.2297253308337863'))
# (120, datetime.datetime(2000, 1, 1, 1, 59), Decimal('-0.12794022765637722'))
# (121, datetime.datetime(2000, 1, 1, 2, 0), Decimal('-1.7294529592606536'))
# (122, datetime.datetime(2000, 1, 1, 2, 1), Decimal('-1.0528745911290418'))
# (123, datetime.datetime(2000, 1, 1, 2, 2), Decimal('-0.6664388252571068'))
# (124, datetime.datetime(2000, 1, 1, 2, 3), Decimal('0.48871951118488366'))
# (125, datetime.datetime(2000, 1, 1, 2, 4), Decimal('0.574199029837057'))
# (126, datetime.datetime(2000, 1, 1, 2, 5), Decimal('-0.07692501105198375'))
# (127, datetime.datetime(2000, 1, 1, 2, 6), Decimal('0.8948012095147042'))
# (128, datetime.datetime(2000, 1, 1, 2, 7), Decimal('-0.6381429067851513'))
# (129, datetime.datetime(2000, 1, 1, 2, 8), Decimal('-1.9932708168746223'))
# (130, datetime.datetime(2000, 1, 1, 2, 9), Decimal('1.0179352422415435'))
# (131, datetime.datetime(2000, 1, 1, 2, 10), Decimal('1.2952375171918664'))
# (132, datetime.datetime(2000, 1, 1, 2, 11), Decimal('0.38877708707869235'))
# (133, datetime.datetime(2000, 1, 1, 2, 12), Decimal('0.9518456811857546'))
# (134, datetime.datetime(2000, 1, 1, 2, 13), Decimal('-0.45875300434144783'))
# (135, datetime.datetime(2000, 1, 1, 2, 14), Decimal('-0.5871286574828696'))
# (136, datetime.datetime(2000, 1, 1, 2, 15), Decimal('0.34595414224351084'))
# (137, datetime.datetime(2000, 1, 1, 2, 16), Decimal('-0.2248033420153766'))
# (138, datetime.datetime(2000, 1, 1, 2, 17), Decimal('-0.1391115815764209'))
# (139, datetime.datetime(2000, 1, 1, 2, 18), Decimal('0.7905979483783239'))
# (140, datetime.datetime(2000, 1, 1, 2, 19), Decimal('-0.019241436162382226'))
# (141, datetime.datetime(2000, 1, 1, 2, 20), Decimal('-0.23821500740263127'))
# (142, datetime.datetime(2000, 1, 1, 2, 21), Decimal('-0.34819357153389535'))
# (143, datetime.datetime(2000, 1, 1, 2, 22), Decimal('-0.3453181065211894'))
# (144, datetime.datetime(2000, 1, 1, 2, 23), Decimal('0.5049385712776351'))
# (145, datetime.datetime(2000, 1, 1, 2, 24), Decimal('-0.41498255269271633'))
# (146, datetime.datetime(2000, 1, 1, 2, 25), Decimal('-0.3456820481048744'))
# (147, datetime.datetime(2000, 1, 1, 2, 26), Decimal('0.8417559185293205'))
# (148, datetime.datetime(2000, 1, 1, 2, 27), Decimal('-0.460818618594708'))
# (149, datetime.datetime(2000, 1, 1, 2, 28), Decimal('0.11690795994244682'))
# (150, datetime.datetime(2000, 1, 1, 2, 29), Decimal('-0.7457934869919645'))
# (151, datetime.datetime(2000, 1, 1, 2, 30), Decimal('-0.8257863236831465'))
# (152, datetime.datetime(2000, 1, 1, 2, 31), Decimal('-2.0658889161168488'))
# (153, datetime.datetime(2000, 1, 1, 2, 32), Decimal('-1.1066895605537934'))
# (154, datetime.datetime(2000, 1, 1, 2, 33), Decimal('0.6453183847887888'))
# (155, datetime.datetime(2000, 1, 1, 2, 34), Decimal('-0.07424931506379356'))
# (156, datetime.datetime(2000, 1, 1, 2, 35), Decimal('-0.6489813120540829'))
# (157, datetime.datetime(2000, 1, 1, 2, 36), Decimal('-0.13632151191678085'))
# (158, datetime.datetime(2000, 1, 1, 2, 37), Decimal('0.3780057752431089'))
# (159, datetime.datetime(2000, 1, 1, 2, 38), Decimal('-1.1590496699380168'))
# (160, datetime.datetime(2000, 1, 1, 2, 39), Decimal('0.385695879107649'))
# (161, datetime.datetime(2000, 1, 1, 2, 40), Decimal('-0.7784359836040422'))
# (162, datetime.datetime(2000, 1, 1, 2, 41), Decimal('-0.20961871041741814'))
# (163, datetime.datetime(2000, 1, 1, 2, 42), Decimal('0.05556998451519818'))
# (164, datetime.datetime(2000, 1, 1, 2, 43), Decimal('-0.2848829857496173'))
# (165, datetime.datetime(2000, 1, 1, 2, 44), Decimal('0.9836508812565622'))
# (166, datetime.datetime(2000, 1, 1, 2, 45), Decimal('-0.2639489745779357'))
# (167, datetime.datetime(2000, 1, 1, 2, 46), Decimal('-0.3726518873137505'))
# (168, datetime.datetime(2000, 1, 1, 2, 47), Decimal('-0.41677050402522836'))
# (169, datetime.datetime(2000, 1, 1, 2, 48), Decimal('0.3360563392303894'))
# (170, datetime.datetime(2000, 1, 1, 2, 49), Decimal('0.4787569099595015'))
# (171, datetime.datetime(2000, 1, 1, 2, 50), Decimal('-0.2392559275685735'))
# (172, datetime.datetime(2000, 1, 1, 2, 51), Decimal('-0.20125921634840974'))
# (173, datetime.datetime(2000, 1, 1, 2, 52), Decimal('1.0117293463843235'))
# (174, datetime.datetime(2000, 1, 1, 2, 53), Decimal('1.0413807857639212'))
# (175, datetime.datetime(2000, 1, 1, 2, 54), Decimal('-0.8791001196725614'))
# (176, datetime.datetime(2000, 1, 1, 2, 55), Decimal('1.1981736757945238'))
# (177, datetime.datetime(2000, 1, 1, 2, 56), Decimal('0.28783045556824255'))
# (178, datetime.datetime(2000, 1, 1, 2, 57), Decimal('-0.4381755528401162'))
# (179, datetime.datetime(2000, 1, 1, 2, 58), Decimal('-0.3740597625960147'))
# (180, datetime.datetime(2000, 1, 1, 2, 59), Decimal('-1.4811583602852108'))
# (181, datetime.datetime(2000, 1, 1, 3, 0), Decimal('-1.108605709793106'))
# (182, datetime.datetime(2000, 1, 1, 3, 1), Decimal('-1.1838271672200151'))
# (183, datetime.datetime(2000, 1, 1, 3, 2), Decimal('0.8516752872680617'))
# (184, datetime.datetime(2000, 1, 1, 3, 3), Decimal('0.1610196276403912'))
# (185, datetime.datetime(2000, 1, 1, 3, 4), Decimal('1.4773220145111763'))
# (186, datetime.datetime(2000, 1, 1, 3, 5), Decimal('1.2647551303436522'))
# (187, datetime.datetime(2000, 1, 1, 3, 6), Decimal('-1.241001250089981'))
# (188, datetime.datetime(2000, 1, 1, 3, 7), Decimal('-0.5298784042695037'))
# (189, datetime.datetime(2000, 1, 1, 3, 8), Decimal('-1.727988455736157'))
# (190, datetime.datetime(2000, 1, 1, 3, 9), Decimal('0.7111658390357313'))
# (191, datetime.datetime(2000, 1, 1, 3, 10), Decimal('-0.0906945357849281'))
# (192, datetime.datetime(2000, 1, 1, 3, 11), Decimal('-0.4746085192861639'))
# (193, datetime.datetime(2000, 1, 1, 3, 12), Decimal('0.5608193492133863'))
# (194, datetime.datetime(2000, 1, 1, 3, 13), Decimal('-0.4526592131563975'))
# (195, datetime.datetime(2000, 1, 1, 3, 14), Decimal('0.5308472775802783'))
# (196, datetime.datetime(2000, 1, 1, 3, 15), Decimal('-0.40786017498531785'))
# (197, datetime.datetime(2000, 1, 1, 3, 16), Decimal('-1.2219897723990918'))
# (198, datetime.datetime(2000, 1, 1, 3, 17), Decimal('-0.6993463302400847'))
# (199, datetime.datetime(2000, 1, 1, 3, 18), Decimal('1.4282322880274196'))
# (200, datetime.datetime(2000, 1, 1, 3, 19), Decimal('0.44086152142396123'))
# (201, datetime.datetime(2000, 1, 1, 3, 20), Decimal('0.29425130255216597'))
# (202, datetime.datetime(2000, 1, 1, 3, 21), Decimal('-1.0286449636832249'))
# (203, datetime.datetime(2000, 1, 1, 3, 22), Decimal('-1.4108162148926477'))
# (204, datetime.datetime(2000, 1, 1, 3, 23), Decimal('-0.581742409373852'))
# (205, datetime.datetime(2000, 1, 1, 3, 24), Decimal('0.9749548973444602'))
# (206, datetime.datetime(2000, 1, 1, 3, 25), Decimal('-1.6432653405492945'))
# (207, datetime.datetime(2000, 1, 1, 3, 26), Decimal('-1.261517385461908'))
# (208, datetime.datetime(2000, 1, 1, 3, 27), Decimal('-0.6679453682464326'))
# (209, datetime.datetime(2000, 1, 1, 3, 28), Decimal('-0.8192225612335334'))
# (210, datetime.datetime(2000, 1, 1, 3, 29), Decimal('0.8926394251468703'))
# (211, datetime.datetime(2000, 1, 1, 3, 30), Decimal('-1.5774676279572746'))
# (212, datetime.datetime(2000, 1, 1, 3, 31), Decimal('0.7839164134286081'))
# (213, datetime.datetime(2000, 1, 1, 3, 32), Decimal('-1.7693802001227426'))
# (214, datetime.datetime(2000, 1, 1, 3, 33), Decimal('-1.2129710035185521'))
# (215, datetime.datetime(2000, 1, 1, 3, 34), Decimal('-0.06370972856731946'))
# (216, datetime.datetime(2000, 1, 1, 3, 35), Decimal('0.11705368274376082'))
# (217, datetime.datetime(2000, 1, 1, 3, 36), Decimal('1.7759629869271318'))
# (218, datetime.datetime(2000, 1, 1, 3, 37), Decimal('-0.0347813862017794'))
# (219, datetime.datetime(2000, 1, 1, 3, 38), Decimal('1.132549454106992'))
# (220, datetime.datetime(2000, 1, 1, 3, 39), Decimal('-1.480297487306203'))
# (221, datetime.datetime(2000, 1, 1, 3, 40), Decimal('-1.5947281581403834'))
# (222, datetime.datetime(2000, 1, 1, 3, 41), Decimal('0.27665298068197547'))
# (223, datetime.datetime(2000, 1, 1, 3, 42), Decimal('-1.9237663646505017'))
# (224, datetime.datetime(2000, 1, 1, 3, 43), Decimal('-0.30412435155678846'))
# (225, datetime.datetime(2000, 1, 1, 3, 44), Decimal('1.197075873783379'))
# (226, datetime.datetime(2000, 1, 1, 3, 45), Decimal('0.5993213565683335'))
# (227, datetime.datetime(2000, 1, 1, 3, 46), Decimal('-0.13837785409814368'))
# (228, datetime.datetime(2000, 1, 1, 3, 47), Decimal('-0.0745146248632942'))
# (229, datetime.datetime(2000, 1, 1, 3, 48), Decimal('-0.6505181574090473'))
# (230, datetime.datetime(2000, 1, 1, 3, 49), Decimal('-1.1338183938998088'))
# (231, datetime.datetime(2000, 1, 1, 3, 50), Decimal('1.4596691072701191'))
# (232, datetime.datetime(2000, 1, 1, 3, 51), Decimal('1.8700606674691167'))
# (233, datetime.datetime(2000, 1, 1, 3, 52), Decimal('0.407973252729933'))
# (234, datetime.datetime(2000, 1, 1, 3, 53), Decimal('0.4859220994917415'))
# (235, datetime.datetime(2000, 1, 1, 3, 54), Decimal('1.4303017521190104'))
# (236, datetime.datetime(2000, 1, 1, 3, 55), Decimal('-0.43986910142735947'))
# (237, datetime.datetime(2000, 1, 1, 3, 56), Decimal('0.30322901995000134'))
# (238, datetime.datetime(2000, 1, 1, 3, 57), Decimal('-1.0426337355090054'))
# (239, datetime.datetime(2000, 1, 1, 3, 58), Decimal('0.8388228593616891'))
# (240, datetime.datetime(2000, 1, 1, 3, 59), Decimal('-0.7761554639912648'))
# (241, datetime.datetime(2000, 1, 1, 4, 0), Decimal('0.8645297370300146'))
# (242, datetime.datetime(2000, 1, 1, 4, 1), Decimal('-0.9710281138744733'))
# (243, datetime.datetime(2000, 1, 1, 4, 2), Decimal('-0.8620787288186527'))
# (244, datetime.datetime(2000, 1, 1, 4, 3), Decimal('1.2621049276021818'))
# (245, datetime.datetime(2000, 1, 1, 4, 4), Decimal('-0.632731508672645'))
# (246, datetime.datetime(2000, 1, 1, 4, 5), Decimal('0.5707218156796704'))
# (247, datetime.datetime(2000, 1, 1, 4, 6), Decimal('0.698454534345193'))
# (248, datetime.datetime(2000, 1, 1, 4, 7), Decimal('0.8287875791960834'))
# (249, datetime.datetime(2000, 1, 1, 4, 8), Decimal('0.9197250697670712'))
# (250, datetime.datetime(2000, 1, 1, 4, 9), Decimal('-2.4292270980544814'))
# (251, datetime.datetime(2000, 1, 1, 4, 10), Decimal('0.8257088349788518'))
# (252, datetime.datetime(2000, 1, 1, 4, 11), Decimal('0.10896031695553496'))
# (253, datetime.datetime(2000, 1, 1, 4, 12), Decimal('-0.37691457524423966'))
# (254, datetime.datetime(2000, 1, 1, 4, 13), Decimal('0.18763274474814906'))
# (255, datetime.datetime(2000, 1, 1, 4, 14), Decimal('-0.8263177874102289'))
# (256, datetime.datetime(2000, 1, 1, 4, 15), Decimal('1.8840845571523073'))
# (257, datetime.datetime(2000, 1, 1, 4, 16), Decimal('-0.49410474734355936'))
# (258, datetime.datetime(2000, 1, 1, 4, 17), Decimal('0.3854819615290272'))
# (259, datetime.datetime(2000, 1, 1, 4, 18), Decimal('-0.2728122573005157'))
# (260, datetime.datetime(2000, 1, 1, 4, 19), Decimal('0.9539333221679542'))
# (261, datetime.datetime(2000, 1, 1, 4, 20), Decimal('1.4382058900482586'))
# (262, datetime.datetime(2000, 1, 1, 4, 21), Decimal('0.10738827643320996'))
# (263, datetime.datetime(2000, 1, 1, 4, 22), Decimal('-0.05375531227428301'))
# (264, datetime.datetime(2000, 1, 1, 4, 23), Decimal('-0.9100657381956068'))
# (265, datetime.datetime(2000, 1, 1, 4, 24), Decimal('-1.1143479630789486'))
# (266, datetime.datetime(2000, 1, 1, 4, 25), Decimal('0.8035799574086895'))
# (267, datetime.datetime(2000, 1, 1, 4, 26), Decimal('-0.4055426440687666'))
# (268, datetime.datetime(2000, 1, 1, 4, 27), Decimal('-0.5815396277577722'))
# (269, datetime.datetime(2000, 1, 1, 4, 28), Decimal('0.6528553248887685'))
# (270, datetime.datetime(2000, 1, 1, 4, 29), Decimal('1.0539128429121947'))
# (271, datetime.datetime(2000, 1, 1, 4, 30), Decimal('-1.2015616805568572'))
# (272, datetime.datetime(2000, 1, 1, 4, 31), Decimal('-0.3767608419785811'))
# (273, datetime.datetime(2000, 1, 1, 4, 32), Decimal('-0.247073292533908'))
# (274, datetime.datetime(2000, 1, 1, 4, 33), Decimal('0.0891713568419986'))
# (275, datetime.datetime(2000, 1, 1, 4, 34), Decimal('-2.5097314385675205'))
# (276, datetime.datetime(2000, 1, 1, 4, 35), Decimal('-1.0754513701216233'))
# (277, datetime.datetime(2000, 1, 1, 4, 36), Decimal('0.24008130970396352'))
# (278, datetime.datetime(2000, 1, 1, 4, 37), Decimal('-0.7623442777111903'))
# (279, datetime.datetime(2000, 1, 1, 4, 38), Decimal('0.6413006903260536'))
# (280, datetime.datetime(2000, 1, 1, 4, 39), Decimal('-1.3825763542425729'))
# (281, datetime.datetime(2000, 1, 1, 4, 40), Decimal('0.518537794502403'))
# (282, datetime.datetime(2000, 1, 1, 4, 41), Decimal('-1.2359622854830716'))
# (283, datetime.datetime(2000, 1, 1, 4, 42), Decimal('-0.18961911179813054'))
# (284, datetime.datetime(2000, 1, 1, 4, 43), Decimal('1.0211602680736582'))
# (285, datetime.datetime(2000, 1, 1, 4, 44), Decimal('0.9066267916581279'))
# (286, datetime.datetime(2000, 1, 1, 4, 45), Decimal('0.0732051286085259'))
# (287, datetime.datetime(2000, 1, 1, 4, 46), Decimal('-0.37159044815314823'))
# (288, datetime.datetime(2000, 1, 1, 4, 47), Decimal('-1.7081147906054421'))
# (289, datetime.datetime(2000, 1, 1, 4, 48), Decimal('0.9917989209845043'))
# (290, datetime.datetime(2000, 1, 1, 4, 49), Decimal('-0.17864618674945137'))
# (291, datetime.datetime(2000, 1, 1, 4, 50), Decimal('-1.6002287930934498'))
# (292, datetime.datetime(2000, 1, 1, 4, 51), Decimal('-0.30931569403787884'))
# (293, datetime.datetime(2000, 1, 1, 4, 52), Decimal('0.7944380969749265'))
# (294, datetime.datetime(2000, 1, 1, 4, 53), Decimal('0.8911187718333244'))
# (295, datetime.datetime(2000, 1, 1, 4, 54), Decimal('1.3746849775684122'))
# (296, datetime.datetime(2000, 1, 1, 4, 55), Decimal('1.1961291755405854'))
# (297, datetime.datetime(2000, 1, 1, 4, 56), Decimal('-1.0108520650116843'))
# (298, datetime.datetime(2000, 1, 1, 4, 57), Decimal('-0.7750184715328604'))
# (299, datetime.datetime(2000, 1, 1, 4, 58), Decimal('-0.37216670625362513'))
# (300, datetime.datetime(2000, 1, 1, 4, 59), Decimal('-1.0533553601750842'))
# (301, datetime.datetime(2000, 1, 1, 5, 0), Decimal('1.0580977104103961'))
# (302, datetime.datetime(2000, 1, 1, 5, 1), Decimal('-0.03738131792575114'))
# (303, datetime.datetime(2000, 1, 1, 5, 2), Decimal('-0.03415586883589673'))
# (304, datetime.datetime(2000, 1, 1, 5, 3), Decimal('-0.4442766852478236'))
# (305, datetime.datetime(2000, 1, 1, 5, 4), Decimal('0.6287456694548917'))
# (306, datetime.datetime(2000, 1, 1, 5, 5), Decimal('-0.9869638759906411'))
# (307, datetime.datetime(2000, 1, 1, 5, 6), Decimal('-1.6102078912083053'))
# (308, datetime.datetime(2000, 1, 1, 5, 7), Decimal('0.7599692356702304'))
# (309, datetime.datetime(2000, 1, 1, 5, 8), Decimal('-0.2933958443365477'))
# (310, datetime.datetime(2000, 1, 1, 5, 9), Decimal('0.7196708622756252'))
# (311, datetime.datetime(2000, 1, 1, 5, 10), Decimal('-0.6485749174327686'))
# (312, datetime.datetime(2000, 1, 1, 5, 11), Decimal('0.9047823545205501'))
# (313, datetime.datetime(2000, 1, 1, 5, 12), Decimal('-0.15695840724014037'))
# (314, datetime.datetime(2000, 1, 1, 5, 13), Decimal('-0.9074359393261439'))
# (315, datetime.datetime(2000, 1, 1, 5, 14), Decimal('2.1658073690678283'))
# (316, datetime.datetime(2000, 1, 1, 5, 15), Decimal('0.2817524178872631'))
# (317, datetime.datetime(2000, 1, 1, 5, 16), Decimal('1.2092352497963483'))
# (318, datetime.datetime(2000, 1, 1, 5, 17), Decimal('-1.2998192464135432'))
# (319, datetime.datetime(2000, 1, 1, 5, 18), Decimal('0.10151932228406008'))
# (320, datetime.datetime(2000, 1, 1, 5, 19), Decimal('1.0802080995385317'))
# (321, datetime.datetime(2000, 1, 1, 5, 20), Decimal('-0.09446277922067293'))
# (322, datetime.datetime(2000, 1, 1, 5, 21), Decimal('0.11833664727247471'))
# (323, datetime.datetime(2000, 1, 1, 5, 22), Decimal('-0.6944279816361294'))
# (324, datetime.datetime(2000, 1, 1, 5, 23), Decimal('-0.5844045698324882'))
# (325, datetime.datetime(2000, 1, 1, 5, 24), Decimal('-0.4408757940686353'))
# (326, datetime.datetime(2000, 1, 1, 5, 25), Decimal('0.4367333066934715'))
# (327, datetime.datetime(2000, 1, 1, 5, 26), Decimal('-0.21729420030096946'))
# (328, datetime.datetime(2000, 1, 1, 5, 27), Decimal('0.6622397877950017'))
# (329, datetime.datetime(2000, 1, 1, 5, 28), Decimal('1.1876077748449836'))
# (330, datetime.datetime(2000, 1, 1, 5, 29), Decimal('-1.22930916621207'))
# (331, datetime.datetime(2000, 1, 1, 5, 30), Decimal('0.07609126440056035'))
# (332, datetime.datetime(2000, 1, 1, 5, 31), Decimal('0.211325090284973'))
# (333, datetime.datetime(2000, 1, 1, 5, 32), Decimal('0.07025219309488136'))
# (334, datetime.datetime(2000, 1, 1, 5, 33), Decimal('0.3036309616865702'))
# (335, datetime.datetime(2000, 1, 1, 5, 34), Decimal('2.40908867540091'))
# (336, datetime.datetime(2000, 1, 1, 5, 35), Decimal('-1.1387972914303688'))
# (337, datetime.datetime(2000, 1, 1, 5, 36), Decimal('1.6762555757425646'))
# (338, datetime.datetime(2000, 1, 1, 5, 37), Decimal('0.3678220325931189'))
# (339, datetime.datetime(2000, 1, 1, 5, 38), Decimal('-0.43675721495902337'))
# (340, datetime.datetime(2000, 1, 1, 5, 39), Decimal('-0.6451961788345697'))
# (341, datetime.datetime(2000, 1, 1, 5, 40), Decimal('1.631953955685368'))
# (342, datetime.datetime(2000, 1, 1, 5, 41), Decimal('-0.15920758001283308'))
# (343, datetime.datetime(2000, 1, 1, 5, 42), Decimal('-3.1195094357912674'))
# (344, datetime.datetime(2000, 1, 1, 5, 43), Decimal('2.296373115190157'))
# (345, datetime.datetime(2000, 1, 1, 5, 44), Decimal('1.9705922640613027'))
# (346, datetime.datetime(2000, 1, 1, 5, 45), Decimal('-1.8331503990118891'))
# (347, datetime.datetime(2000, 1, 1, 5, 46), Decimal('0.11601967057880858'))
# (348, datetime.datetime(2000, 1, 1, 5, 47), Decimal('-0.38505262251484973'))
# (349, datetime.datetime(2000, 1, 1, 5, 48), Decimal('-0.643275946782439'))
# (350, datetime.datetime(2000, 1, 1, 5, 49), Decimal('0.40639825692785875'))
# (351, datetime.datetime(2000, 1, 1, 5, 50), Decimal('1.0557287851634298'))
# (352, datetime.datetime(2000, 1, 1, 5, 51), Decimal('0.5358737678616203'))
# (353, datetime.datetime(2000, 1, 1, 5, 52), Decimal('-0.2987520494484001'))
# (354, datetime.datetime(2000, 1, 1, 5, 53), Decimal('0.13239838832977088'))
# (355, datetime.datetime(2000, 1, 1, 5, 54), Decimal('-0.6707952331113114'))
# (356, datetime.datetime(2000, 1, 1, 5, 55), Decimal('-0.3350068252353827'))
# (357, datetime.datetime(2000, 1, 1, 5, 56), Decimal('-0.5953297916331954'))
# (358, datetime.datetime(2000, 1, 1, 5, 57), Decimal('-0.6253728418991006'))
# (359, datetime.datetime(2000, 1, 1, 5, 58), Decimal('0.26249445118213915'))
# (360, datetime.datetime(2000, 1, 1, 5, 59), Decimal('2.4964173156523155'))
# (361, datetime.datetime(2000, 1, 1, 6, 0), Decimal('0.5134326698620929'))
# (362, datetime.datetime(2000, 1, 1, 6, 1), Decimal('-1.1665668394572495'))
# (363, datetime.datetime(2000, 1, 1, 6, 2), Decimal('-0.11706914785101351'))
# (364, datetime.datetime(2000, 1, 1, 6, 3), Decimal('-0.4713112293443076'))
# (365, datetime.datetime(2000, 1, 1, 6, 4), Decimal('-0.4455011261973364'))
# (366, datetime.datetime(2000, 1, 1, 6, 5), Decimal('1.6096352049480873'))
# (367, datetime.datetime(2000, 1, 1, 6, 6), Decimal('1.170951336612624'))
# (368, datetime.datetime(2000, 1, 1, 6, 7), Decimal('-1.2037406536002053'))
# (369, datetime.datetime(2000, 1, 1, 6, 8), Decimal('0.5772185499701676'))
# (370, datetime.datetime(2000, 1, 1, 6, 9), Decimal('-0.32936420820216916'))
# (371, datetime.datetime(2000, 1, 1, 6, 10), Decimal('-0.8902659951121841'))
# (372, datetime.datetime(2000, 1, 1, 6, 11), Decimal('-1.8614207746326905'))
# (373, datetime.datetime(2000, 1, 1, 6, 12), Decimal('-0.6155953569870591'))
# (374, datetime.datetime(2000, 1, 1, 6, 13), Decimal('0.11603031777219168'))
# (375, datetime.datetime(2000, 1, 1, 6, 14), Decimal('0.4124762784926035'))
# (376, datetime.datetime(2000, 1, 1, 6, 15), Decimal('0.5188479644013695'))
# (377, datetime.datetime(2000, 1, 1, 6, 16), Decimal('1.0672269633888676'))
# (378, datetime.datetime(2000, 1, 1, 6, 17), Decimal('0.8134956328726746'))
# (379, datetime.datetime(2000, 1, 1, 6, 18), Decimal('-0.6346539485726039'))
# (380, datetime.datetime(2000, 1, 1, 6, 19), Decimal('0.3867323525658468'))
# (381, datetime.datetime(2000, 1, 1, 6, 20), Decimal('-0.12888265884852293'))
# (382, datetime.datetime(2000, 1, 1, 6, 21), Decimal('-1.4587713704884886'))
# (383, datetime.datetime(2000, 1, 1, 6, 22), Decimal('0.8977874986795469'))
# (384, datetime.datetime(2000, 1, 1, 6, 23), Decimal('1.3284740072010495'))
# (385, datetime.datetime(2000, 1, 1, 6, 24), Decimal('1.0062406881648152'))
# (386, datetime.datetime(2000, 1, 1, 6, 25), Decimal('-0.9803037020039937'))
# (387, datetime.datetime(2000, 1, 1, 6, 26), Decimal('-0.06255143324623304'))
# (388, datetime.datetime(2000, 1, 1, 6, 27), Decimal('1.2569890853956511'))
# (389, datetime.datetime(2000, 1, 1, 6, 28), Decimal('-1.8096977252339226'))
# (390, datetime.datetime(2000, 1, 1, 6, 29), Decimal('-2.4153676713424908'))
# (391, datetime.datetime(2000, 1, 1, 6, 30), Decimal('0.685021469929435'))
# (392, datetime.datetime(2000, 1, 1, 6, 31), Decimal('-1.224882587260778'))
# (393, datetime.datetime(2000, 1, 1, 6, 32), Decimal('-0.7470373476700785'))
# (394, datetime.datetime(2000, 1, 1, 6, 33), Decimal('0.7761828913890021'))
# (395, datetime.datetime(2000, 1, 1, 6, 34), Decimal('0.4161593612259123'))
# (396, datetime.datetime(2000, 1, 1, 6, 35), Decimal('-0.13168326921553872'))
# (397, datetime.datetime(2000, 1, 1, 6, 36), Decimal('-1.4500006565335197'))
# (398, datetime.datetime(2000, 1, 1, 6, 37), Decimal('0.8693763429412122'))
# (399, datetime.datetime(2000, 1, 1, 6, 38), Decimal('-2.5843660390089602'))
# (400, datetime.datetime(2000, 1, 1, 6, 39), Decimal('-0.5911364184213184'))
# (401, datetime.datetime(2000, 1, 1, 6, 40), Decimal('-1.0045259970431577'))
# (402, datetime.datetime(2000, 1, 1, 6, 41), Decimal('1.0608268821354472'))
# (403, datetime.datetime(2000, 1, 1, 6, 42), Decimal('0.44042643892757005'))
# (404, datetime.datetime(2000, 1, 1, 6, 43), Decimal('0.4603639447015087'))
# (405, datetime.datetime(2000, 1, 1, 6, 44), Decimal('-0.6125206557403392'))
# (406, datetime.datetime(2000, 1, 1, 6, 45), Decimal('1.2070555307729993'))
# (407, datetime.datetime(2000, 1, 1, 6, 46), Decimal('1.4741718829256754'))
# (408, datetime.datetime(2000, 1, 1, 6, 47), Decimal('-0.8980616803741857'))
# (409, datetime.datetime(2000, 1, 1, 6, 48), Decimal('1.1791278478894274'))
# (410, datetime.datetime(2000, 1, 1, 6, 49), Decimal('0.12269294754733026'))
# (411, datetime.datetime(2000, 1, 1, 6, 50), Decimal('-1.4347859423516152'))
# (412, datetime.datetime(2000, 1, 1, 6, 51), Decimal('1.0273268885962206'))
# (413, datetime.datetime(2000, 1, 1, 6, 52), Decimal('-0.19110508286847477'))
# (414, datetime.datetime(2000, 1, 1, 6, 53), Decimal('0.8994015599823244'))
# (415, datetime.datetime(2000, 1, 1, 6, 54), Decimal('-0.9474335206566109'))
# (416, datetime.datetime(2000, 1, 1, 6, 55), Decimal('0.2307029849905741'))
# (417, datetime.datetime(2000, 1, 1, 6, 56), Decimal('0.1968838436077523'))
# (418, datetime.datetime(2000, 1, 1, 6, 57), Decimal('-0.04623915584716582'))
# (419, datetime.datetime(2000, 1, 1, 6, 58), Decimal('-0.38247651670378513'))
# (420, datetime.datetime(2000, 1, 1, 6, 59), Decimal('0.027405458420609527'))
# (421, datetime.datetime(2000, 1, 1, 7, 0), Decimal('-0.4374222753922857'))
# (422, datetime.datetime(2000, 1, 1, 7, 1), Decimal('1.0833797294458054'))
# (423, datetime.datetime(2000, 1, 1, 7, 2), Decimal('0.49110875388538766'))
# (424, datetime.datetime(2000, 1, 1, 7, 3), Decimal('-0.9193427630990463'))
# (425, datetime.datetime(2000, 1, 1, 7, 4), Decimal('1.3295942342422136'))
# (426, datetime.datetime(2000, 1, 1, 7, 5), Decimal('0.3638412741716025'))
# (427, datetime.datetime(2000, 1, 1, 7, 6), Decimal('-1.311434233799414'))
# (428, datetime.datetime(2000, 1, 1, 7, 7), Decimal('0.8845455357972963'))
# (429, datetime.datetime(2000, 1, 1, 7, 8), Decimal('-1.0886255876258983'))
# (430, datetime.datetime(2000, 1, 1, 7, 9), Decimal('-0.16596256807064863'))
# (431, datetime.datetime(2000, 1, 1, 7, 10), Decimal('2.2893320656882494'))
# (432, datetime.datetime(2000, 1, 1, 7, 11), Decimal('-0.9100066165833645'))
# (433, datetime.datetime(2000, 1, 1, 7, 12), Decimal('1.5548122565053122'))
# (434, datetime.datetime(2000, 1, 1, 7, 13), Decimal('-0.8709261010508911'))
# (435, datetime.datetime(2000, 1, 1, 7, 14), Decimal('0.436059471957653'))
# (436, datetime.datetime(2000, 1, 1, 7, 15), Decimal('0.41370025844625086'))
# (437, datetime.datetime(2000, 1, 1, 7, 16), Decimal('-0.08451195335777163'))
# (438, datetime.datetime(2000, 1, 1, 7, 17), Decimal('-0.16941214443618607'))
# (439, datetime.datetime(2000, 1, 1, 7, 18), Decimal('1.5166864531599855'))
# (440, datetime.datetime(2000, 1, 1, 7, 19), Decimal('-0.6487015555710425'))
# (441, datetime.datetime(2000, 1, 1, 7, 20), Decimal('-0.21464365144334496'))
# (442, datetime.datetime(2000, 1, 1, 7, 21), Decimal('2.607023277806435'))
# (443, datetime.datetime(2000, 1, 1, 7, 22), Decimal('-0.7850606706989439'))
# (444, datetime.datetime(2000, 1, 1, 7, 23), Decimal('-1.8790904355930649'))
# (445, datetime.datetime(2000, 1, 1, 7, 24), Decimal('-0.45352978440374914'))
# (446, datetime.datetime(2000, 1, 1, 7, 25), Decimal('0.7203703213928476'))
# (447, datetime.datetime(2000, 1, 1, 7, 26), Decimal('-1.4351389263810201'))
# (448, datetime.datetime(2000, 1, 1, 7, 27), Decimal('0.40008785575886924'))
# (449, datetime.datetime(2000, 1, 1, 7, 28), Decimal('-1.117917977116511'))
# (450, datetime.datetime(2000, 1, 1, 7, 29), Decimal('1.891771419745415'))
# (451, datetime.datetime(2000, 1, 1, 7, 30), Decimal('-0.6932249780575249'))
# (452, datetime.datetime(2000, 1, 1, 7, 31), Decimal('-0.3839749202678951'))
# (453, datetime.datetime(2000, 1, 1, 7, 32), Decimal('0.4596041322724226'))
# (454, datetime.datetime(2000, 1, 1, 7, 33), Decimal('1.1417138563406717'))
# (455, datetime.datetime(2000, 1, 1, 7, 34), Decimal('-1.0193421186627103'))
# (456, datetime.datetime(2000, 1, 1, 7, 35), Decimal('-1.4330799405210388'))
# (457, datetime.datetime(2000, 1, 1, 7, 36), Decimal('-0.2713396749798898'))
# (458, datetime.datetime(2000, 1, 1, 7, 37), Decimal('-0.5701576045775153'))
# (459, datetime.datetime(2000, 1, 1, 7, 38), Decimal('-0.7694457753584041'))
# (460, datetime.datetime(2000, 1, 1, 7, 39), Decimal('-0.5219821696526832'))
# (461, datetime.datetime(2000, 1, 1, 7, 40), Decimal('0.05363142794070142'))
# (462, datetime.datetime(2000, 1, 1, 7, 41), Decimal('-0.7923883422218327'))
# (463, datetime.datetime(2000, 1, 1, 7, 42), Decimal('-0.2715700883046166'))
# (464, datetime.datetime(2000, 1, 1, 7, 43), Decimal('-1.7333274496686737'))
# (465, datetime.datetime(2000, 1, 1, 7, 44), Decimal('-1.5280446368378962'))
# (466, datetime.datetime(2000, 1, 1, 7, 45), Decimal('-1.6970121519645005'))
# (467, datetime.datetime(2000, 1, 1, 7, 46), Decimal('0.015485698705529207'))
# (468, datetime.datetime(2000, 1, 1, 7, 47), Decimal('-2.0310577506592558'))
# (469, datetime.datetime(2000, 1, 1, 7, 48), Decimal('-0.8253890214856685'))
# (470, datetime.datetime(2000, 1, 1, 7, 49), Decimal('-0.3885436033013478'))
# (471, datetime.datetime(2000, 1, 1, 7, 50), Decimal('1.2900132047632507'))
# (472, datetime.datetime(2000, 1, 1, 7, 51), Decimal('-1.5882790817683787'))
# (473, datetime.datetime(2000, 1, 1, 7, 52), Decimal('0.2822898428824851'))
# (474, datetime.datetime(2000, 1, 1, 7, 53), Decimal('-1.0295158695051927'))
# (475, datetime.datetime(2000, 1, 1, 7, 54), Decimal('2.4364458009046426'))
# (476, datetime.datetime(2000, 1, 1, 7, 55), Decimal('-0.17299957632796623'))
# (477, datetime.datetime(2000, 1, 1, 7, 56), Decimal('-0.0489809229470247'))
# (478, datetime.datetime(2000, 1, 1, 7, 57), Decimal('-0.2871746074865419'))
# (479, datetime.datetime(2000, 1, 1, 7, 58), Decimal('0.17548015976386697'))
# (480, datetime.datetime(2000, 1, 1, 7, 59), Decimal('-0.09642853028721904'))
# (481, datetime.datetime(2000, 1, 1, 8, 0), Decimal('-2.4194560565923195'))
# (482, datetime.datetime(2000, 1, 1, 8, 1), Decimal('1.174865800481475'))
# (483, datetime.datetime(2000, 1, 1, 8, 2), Decimal('0.4045519234783882'))
# (484, datetime.datetime(2000, 1, 1, 8, 3), Decimal('2.033885655797088'))
# (485, datetime.datetime(2000, 1, 1, 8, 4), Decimal('-0.4280579366265753'))
# (486, datetime.datetime(2000, 1, 1, 8, 5), Decimal('-1.616237007684048'))
# (487, datetime.datetime(2000, 1, 1, 8, 6), Decimal('-0.36395293300460585'))
# (488, datetime.datetime(2000, 1, 1, 8, 7), Decimal('-0.643934896842951'))
# (489, datetime.datetime(2000, 1, 1, 8, 8), Decimal('-1.8617276908932843'))
# (490, datetime.datetime(2000, 1, 1, 8, 9), Decimal('0.5516211919250186'))
# (491, datetime.datetime(2000, 1, 1, 8, 10), Decimal('0.16929060290209816'))
# (492, datetime.datetime(2000, 1, 1, 8, 11), Decimal('-0.3987621349174462'))
# (493, datetime.datetime(2000, 1, 1, 8, 12), Decimal('-0.03690412485782206'))
# (494, datetime.datetime(2000, 1, 1, 8, 13), Decimal('0.017486406346543536'))
# (495, datetime.datetime(2000, 1, 1, 8, 14), Decimal('0.573344619278457'))
# (496, datetime.datetime(2000, 1, 1, 8, 15), Decimal('-0.6182101545155362'))
# (497, datetime.datetime(2000, 1, 1, 8, 16), Decimal('-0.38595465410512164'))
# (498, datetime.datetime(2000, 1, 1, 8, 17), Decimal('0.26871601679912466'))
# (499, datetime.datetime(2000, 1, 1, 8, 18), Decimal('0.721080347878252'))
# (500, datetime.datetime(2000, 1, 1, 8, 19), Decimal('-0.1764648641723117'))
# (501, datetime.datetime(2000, 1, 1, 8, 20), Decimal('-0.5346490739150691'))
# (502, datetime.datetime(2000, 1, 1, 8, 21), Decimal('-0.05840012205431822'))
# (503, datetime.datetime(2000, 1, 1, 8, 22), Decimal('0.4448162588381929'))
# (504, datetime.datetime(2000, 1, 1, 8, 23), Decimal('0.6818897153708146'))
# (505, datetime.datetime(2000, 1, 1, 8, 24), Decimal('1.9768060484117715'))
# (506, datetime.datetime(2000, 1, 1, 8, 25), Decimal('1.3874030207597807'))
# (507, datetime.datetime(2000, 1, 1, 8, 26), Decimal('-2.0142891766145365'))
# (508, datetime.datetime(2000, 1, 1, 8, 27), Decimal('-0.3566502220799703'))
# (509, datetime.datetime(2000, 1, 1, 8, 28), Decimal('0.028138311085909046'))
# (510, datetime.datetime(2000, 1, 1, 8, 29), Decimal('1.3898123871809678'))
# (511, datetime.datetime(2000, 1, 1, 8, 30), Decimal('-0.6220900118893621'))
# (512, datetime.datetime(2000, 1, 1, 8, 31), Decimal('-1.188030932706824'))
# (513, datetime.datetime(2000, 1, 1, 8, 32), Decimal('1.0972395944948055'))
# (514, datetime.datetime(2000, 1, 1, 8, 33), Decimal('-1.5895061914942443'))
# (515, datetime.datetime(2000, 1, 1, 8, 34), Decimal('-0.16005267409753707'))
# (516, datetime.datetime(2000, 1, 1, 8, 35), Decimal('-0.7654053032232084'))
# (517, datetime.datetime(2000, 1, 1, 8, 36), Decimal('0.7728781544988355'))
# (518, datetime.datetime(2000, 1, 1, 8, 37), Decimal('-0.7011350787364572'))
# (519, datetime.datetime(2000, 1, 1, 8, 38), Decimal('-0.07089702535188765'))
# (520, datetime.datetime(2000, 1, 1, 8, 39), Decimal('-2.0241002157361017'))
# (521, datetime.datetime(2000, 1, 1, 8, 40), Decimal('-2.0278681651762915'))
# (522, datetime.datetime(2000, 1, 1, 8, 41), Decimal('-0.4214191842544513'))
# (523, datetime.datetime(2000, 1, 1, 8, 42), Decimal('0.5750672705808698'))
# (524, datetime.datetime(2000, 1, 1, 8, 43), Decimal('0.21938669873963362'))
# (525, datetime.datetime(2000, 1, 1, 8, 44), Decimal('0.08006474963561647'))
# (526, datetime.datetime(2000, 1, 1, 8, 45), Decimal('0.7238773395117176'))
# (527, datetime.datetime(2000, 1, 1, 8, 46), Decimal('0.5521638582503747'))
# (528, datetime.datetime(2000, 1, 1, 8, 47), Decimal('2.1960626782147044'))
# (529, datetime.datetime(2000, 1, 1, 8, 48), Decimal('0.16257970236054423'))
# (530, datetime.datetime(2000, 1, 1, 8, 49), Decimal('-0.38628462202786745'))
# (531, datetime.datetime(2000, 1, 1, 8, 50), Decimal('1.625656977914718'))
# (532, datetime.datetime(2000, 1, 1, 8, 51), Decimal('0.20544794380532116'))
# (533, datetime.datetime(2000, 1, 1, 8, 52), Decimal('1.0302695026860011'))
# (534, datetime.datetime(2000, 1, 1, 8, 53), Decimal('-1.1198566008750652'))
# (535, datetime.datetime(2000, 1, 1, 8, 54), Decimal('-0.5172702605227565'))
# (536, datetime.datetime(2000, 1, 1, 8, 55), Decimal('-0.09383602238307522'))
# (537, datetime.datetime(2000, 1, 1, 8, 56), Decimal('0.3110144245169755'))
# (538, datetime.datetime(2000, 1, 1, 8, 57), Decimal('-1.2189118338334375'))
# (539, datetime.datetime(2000, 1, 1, 8, 58), Decimal('-0.5066086751926205'))
# (540, datetime.datetime(2000, 1, 1, 8, 59), Decimal('-0.18576744399338174'))
# (541, datetime.datetime(2000, 1, 1, 9, 0), Decimal('0.2996012229179644'))
# (542, datetime.datetime(2000, 1, 1, 9, 1), Decimal('-0.9883233621014857'))
# (543, datetime.datetime(2000, 1, 1, 9, 2), Decimal('0.8469652751222623'))
# (544, datetime.datetime(2000, 1, 1, 9, 3), Decimal('-0.8225344723978146'))
# (545, datetime.datetime(2000, 1, 1, 9, 4), Decimal('0.5009442712618268'))
# (546, datetime.datetime(2000, 1, 1, 9, 5), Decimal('-0.8015963204442049'))
# (547, datetime.datetime(2000, 1, 1, 9, 6), Decimal('-1.9004422028609347'))
# (548, datetime.datetime(2000, 1, 1, 9, 7), Decimal('-0.06328980524115245'))
# (549, datetime.datetime(2000, 1, 1, 9, 8), Decimal('1.1145191752613326'))
# (550, datetime.datetime(2000, 1, 1, 9, 9), Decimal('-1.2067129635866463'))
# (551, datetime.datetime(2000, 1, 1, 9, 10), Decimal('1.7601989022357463'))
# (552, datetime.datetime(2000, 1, 1, 9, 11), Decimal('-1.8586268118391707'))
# (553, datetime.datetime(2000, 1, 1, 9, 12), Decimal('-0.3597427442809554'))
# (554, datetime.datetime(2000, 1, 1, 9, 13), Decimal('-0.10624453870062267'))
# (555, datetime.datetime(2000, 1, 1, 9, 14), Decimal('0.8604773316200418'))
# (556, datetime.datetime(2000, 1, 1, 9, 15), Decimal('2.133024023200288'))
# (557, datetime.datetime(2000, 1, 1, 9, 16), Decimal('1.90999961742561'))
# (558, datetime.datetime(2000, 1, 1, 9, 17), Decimal('1.6411602801888685'))
# (559, datetime.datetime(2000, 1, 1, 9, 18), Decimal('-0.6004518144603854'))
# (560, datetime.datetime(2000, 1, 1, 9, 19), Decimal('-1.3005290027965093'))
# (561, datetime.datetime(2000, 1, 1, 9, 20), Decimal('-1.3807546012177419'))
# (562, datetime.datetime(2000, 1, 1, 9, 21), Decimal('-0.5013937777680024'))
# (563, datetime.datetime(2000, 1, 1, 9, 22), Decimal('-1.8844247608594349'))
# (564, datetime.datetime(2000, 1, 1, 9, 23), Decimal('-0.680589103059114'))
# (565, datetime.datetime(2000, 1, 1, 9, 24), Decimal('-0.5535180864530193'))
# (566, datetime.datetime(2000, 1, 1, 9, 25), Decimal('-0.23376897166644134'))
# (567, datetime.datetime(2000, 1, 1, 9, 26), Decimal('-0.2066794616156664'))
# (568, datetime.datetime(2000, 1, 1, 9, 27), Decimal('-0.8161215664263113'))
# (569, datetime.datetime(2000, 1, 1, 9, 28), Decimal('0.7423071644931792'))
# (570, datetime.datetime(2000, 1, 1, 9, 29), Decimal('-0.4668043379285452'))
# (571, datetime.datetime(2000, 1, 1, 9, 30), Decimal('0.580025324348147'))
# (572, datetime.datetime(2000, 1, 1, 9, 31), Decimal('0.3991637104563755'))
# (573, datetime.datetime(2000, 1, 1, 9, 32), Decimal('-0.3161950805955061'))
# (574, datetime.datetime(2000, 1, 1, 9, 33), Decimal('-0.221788113730272'))
# (575, datetime.datetime(2000, 1, 1, 9, 34), Decimal('0.4332654639927563'))
# (576, datetime.datetime(2000, 1, 1, 9, 35), Decimal('-0.34499297726637995'))
# (577, datetime.datetime(2000, 1, 1, 9, 36), Decimal('-0.8429807705009893'))
# (578, datetime.datetime(2000, 1, 1, 9, 37), Decimal('-0.3246752657232635'))
# (579, datetime.datetime(2000, 1, 1, 9, 38), Decimal('0.34616818900875007'))
# (580, datetime.datetime(2000, 1, 1, 9, 39), Decimal('-0.27026554895901045'))
# (581, datetime.datetime(2000, 1, 1, 9, 40), Decimal('0.6883447330614787'))
# (582, datetime.datetime(2000, 1, 1, 9, 41), Decimal('0.6104152811688296'))
# (583, datetime.datetime(2000, 1, 1, 9, 42), Decimal('0.7234421338963665'))
# (584, datetime.datetime(2000, 1, 1, 9, 43), Decimal('-1.1486840143261452'))
# (585, datetime.datetime(2000, 1, 1, 9, 44), Decimal('-0.9788935874992672'))
# (586, datetime.datetime(2000, 1, 1, 9, 45), Decimal('-0.18844103617913227'))
# (587, datetime.datetime(2000, 1, 1, 9, 46), Decimal('0.5536761405171846'))
# (588, datetime.datetime(2000, 1, 1, 9, 47), Decimal('-0.20488097522430923'))
# (589, datetime.datetime(2000, 1, 1, 9, 48), Decimal('0.9138411484323241'))
# (590, datetime.datetime(2000, 1, 1, 9, 49), Decimal('1.468568853518192'))
# (591, datetime.datetime(2000, 1, 1, 9, 50), Decimal('1.0226322451964838'))
# (592, datetime.datetime(2000, 1, 1, 9, 51), Decimal('-0.994246193455362'))
# (593, datetime.datetime(2000, 1, 1, 9, 52), Decimal('1.22468564426663'))
# (594, datetime.datetime(2000, 1, 1, 9, 53), Decimal('-0.34011777953220634'))
# (595, datetime.datetime(2000, 1, 1, 9, 54), Decimal('0.3656600232520577'))
# (596, datetime.datetime(2000, 1, 1, 9, 55), Decimal('-1.8807016114187232'))
# (597, datetime.datetime(2000, 1, 1, 9, 56), Decimal('-0.43430729622642195'))
# (598, datetime.datetime(2000, 1, 1, 9, 57), Decimal('0.038416810851486016'))
# (599, datetime.datetime(2000, 1, 1, 9, 58), Decimal('1.557816568301751'))
# (600, datetime.datetime(2000, 1, 1, 9, 59), Decimal('1.0093630397814581'))
# (601, datetime.datetime(2000, 1, 1, 10, 0), Decimal('-0.6473577702269092'))
# (602, datetime.datetime(2000, 1, 1, 10, 1), Decimal('-0.012802756908657838'))
# (603, datetime.datetime(2000, 1, 1, 10, 2), Decimal('-1.5942865261147603'))
# (604, datetime.datetime(2000, 1, 1, 10, 3), Decimal('-0.0761600185381651'))
# (605, datetime.datetime(2000, 1, 1, 10, 4), Decimal('0.16555004183662675'))
# (606, datetime.datetime(2000, 1, 1, 10, 5), Decimal('1.1688868017444443'))
# (607, datetime.datetime(2000, 1, 1, 10, 6), Decimal('0.0366844910361413'))
# (608, datetime.datetime(2000, 1, 1, 10, 7), Decimal('0.7626437744091762'))
# (609, datetime.datetime(2000, 1, 1, 10, 8), Decimal('0.2863004903839502'))
# (610, datetime.datetime(2000, 1, 1, 10, 9), Decimal('-1.0155434912226475'))
# (611, datetime.datetime(2000, 1, 1, 10, 10), Decimal('-0.8743854374340546'))
# (612, datetime.datetime(2000, 1, 1, 10, 11), Decimal('-0.7022248939058756'))
# (613, datetime.datetime(2000, 1, 1, 10, 12), Decimal('-0.4895483976827782'))
# (614, datetime.datetime(2000, 1, 1, 10, 13), Decimal('0.02200030176268643'))
# (615, datetime.datetime(2000, 1, 1, 10, 14), Decimal('1.4615141401295595'))
# (616, datetime.datetime(2000, 1, 1, 10, 15), Decimal('-0.44218070689102124'))
# (617, datetime.datetime(2000, 1, 1, 10, 16), Decimal('2.083520877050127'))
# (618, datetime.datetime(2000, 1, 1, 10, 17), Decimal('-0.918705074821725'))
# (619, datetime.datetime(2000, 1, 1, 10, 18), Decimal('1.37398435457948'))
# (620, datetime.datetime(2000, 1, 1, 10, 19), Decimal('0.6277853333531709'))
# (621, datetime.datetime(2000, 1, 1, 10, 20), Decimal('-1.366519882326491'))
# (622, datetime.datetime(2000, 1, 1, 10, 21), Decimal('-1.7787160059212719'))
# (623, datetime.datetime(2000, 1, 1, 10, 22), Decimal('-0.3122030135402975'))
# (624, datetime.datetime(2000, 1, 1, 10, 23), Decimal('-2.022036330028947'))
# (625, datetime.datetime(2000, 1, 1, 10, 24), Decimal('0.6078634785916796'))
# (626, datetime.datetime(2000, 1, 1, 10, 25), Decimal('0.4024437265265976'))
# (627, datetime.datetime(2000, 1, 1, 10, 26), Decimal('0.9717627534008286'))
# (628, datetime.datetime(2000, 1, 1, 10, 27), Decimal('-1.9354831354821616'))
# (629, datetime.datetime(2000, 1, 1, 10, 28), Decimal('0.2484997973116534'))
# (630, datetime.datetime(2000, 1, 1, 10, 29), Decimal('0.7460604290053374'))
# (631, datetime.datetime(2000, 1, 1, 10, 30), Decimal('-0.14071069507969575'))
# (632, datetime.datetime(2000, 1, 1, 10, 31), Decimal('-0.837916670360795'))
# (633, datetime.datetime(2000, 1, 1, 10, 32), Decimal('-0.8588200321096295'))
# (634, datetime.datetime(2000, 1, 1, 10, 33), Decimal('1.486119193806856'))
# (635, datetime.datetime(2000, 1, 1, 10, 34), Decimal('-0.11558464795471694'))
# (636, datetime.datetime(2000, 1, 1, 10, 35), Decimal('1.3519141683885474'))
# ...
# (792, datetime.datetime(2000, 1, 1, 13, 11), Decimal('-1.03436601347251'))
# (793, datetime.datetime(2000, 1, 1, 13, 12), Decimal('-1.2164533221013893'))
# (794, datetime.datetime(2000, 1, 1, 13, 13), Decimal('-1.1620320141496483'))
# (795, datetime.datetime(2000, 1, 1, 13, 14), Decimal('-1.3060933529855567'))
# (796, datetime.datetime(2000, 1, 1, 13, 15), Decimal('0.5319896315450879'))
# (797, datetime.datetime(2000, 1, 1, 13, 16), Decimal('-1.7650424396289497'))
# (798, datetime.datetime(2000, 1, 1, 13, 17), Decimal('0.9669670048055866'))
# (799, datetime.datetime(2000, 1, 1, 13, 18), Decimal('-0.18602413728347594'))
# (800, datetime.datetime(2000, 1, 1, 13, 19), Decimal('-0.8197656621590688'))
# (801, datetime.datetime(2000, 1, 1, 13, 20), Decimal('-0.4869724038169879'))
# (802, datetime.datetime(2000, 1, 1, 13, 21), Decimal('-0.3418344190334561'))
# (803, datetime.datetime(2000, 1, 1, 13, 22), Decimal('0.11790557996984959'))
# (804, datetime.datetime(2000, 1, 1, 13, 23), Decimal('-0.08304865763709929'))
# (805, datetime.datetime(2000, 1, 1, 13, 24), Decimal('-0.5520532434029017'))
# (806, datetime.datetime(2000, 1, 1, 13, 25), Decimal('0.20095295848201095'))
# (807, datetime.datetime(2000, 1, 1, 13, 26), Decimal('-1.0915340117681693'))
# (808, datetime.datetime(2000, 1, 1, 13, 27), Decimal('-0.1320553228880967'))
# (809, datetime.datetime(2000, 1, 1, 13, 28), Decimal('0.4032843611482093'))
# (810, datetime.datetime(2000, 1, 1, 13, 29), Decimal('0.38422682152389126'))
# (811, datetime.datetime(2000, 1, 1, 13, 30), Decimal('-0.642240699721297'))
# (812, datetime.datetime(2000, 1, 1, 13, 31), Decimal('-0.09417857792401346'))
# (813, datetime.datetime(2000, 1, 1, 13, 32), Decimal('1.3612356410223718'))
# (814, datetime.datetime(2000, 1, 1, 13, 33), Decimal('-1.3530423358446992'))
# (815, datetime.datetime(2000, 1, 1, 13, 34), Decimal('-0.5623360637043431'))
# (816, datetime.datetime(2000, 1, 1, 13, 35), Decimal('1.3462709141182503'))
# (817, datetime.datetime(2000, 1, 1, 13, 36), Decimal('-0.7947551915779408'))
# (818, datetime.datetime(2000, 1, 1, 13, 37), Decimal('1.2807511943598402'))
# (819, datetime.datetime(2000, 1, 1, 13, 38), Decimal('0.5782476507591008'))
# (820, datetime.datetime(2000, 1, 1, 13, 39), Decimal('-0.0477075900972047'))
# (821, datetime.datetime(2000, 1, 1, 13, 40), Decimal('1.3908891566258967'))
# (822, datetime.datetime(2000, 1, 1, 13, 41), Decimal('1.3971007551916896'))
# (823, datetime.datetime(2000, 1, 1, 13, 42), Decimal('-0.9981601051646382'))
# (824, datetime.datetime(2000, 1, 1, 13, 43), Decimal('1.2646493956923683'))
# (825, datetime.datetime(2000, 1, 1, 13, 44), Decimal('0.6584887390696427'))
# (826, datetime.datetime(2000, 1, 1, 13, 45), Decimal('-0.9106665350225654'))
# (827, datetime.datetime(2000, 1, 1, 13, 46), Decimal('0.029609776082439657'))
# (828, datetime.datetime(2000, 1, 1, 13, 47), Decimal('-0.9487934043555751'))
# (829, datetime.datetime(2000, 1, 1, 13, 48), Decimal('-1.1294870471556295'))
# (830, datetime.datetime(2000, 1, 1, 13, 49), Decimal('0.03611331572780609'))
# (831, datetime.datetime(2000, 1, 1, 13, 50), Decimal('0.14114135349916793'))
# (832, datetime.datetime(2000, 1, 1, 13, 51), Decimal('-0.8993142543782444'))
# (833, datetime.datetime(2000, 1, 1, 13, 52), Decimal('1.1866480559181922'))
# (834, datetime.datetime(2000, 1, 1, 13, 53), Decimal('-1.0405661928630698'))
# (835, datetime.datetime(2000, 1, 1, 13, 54), Decimal('-2.463986282033961'))
# (836, datetime.datetime(2000, 1, 1, 13, 55), Decimal('-0.1668540469761698'))
# (837, datetime.datetime(2000, 1, 1, 13, 56), Decimal('-0.23316813672824568'))
# (838, datetime.datetime(2000, 1, 1, 13, 57), Decimal('-0.09634761262253491'))
# (839, datetime.datetime(2000, 1, 1, 13, 58), Decimal('-1.4909501728860428'))
# (840, datetime.datetime(2000, 1, 1, 13, 59), Decimal('-0.4864009973637571'))
# (841, datetime.datetime(2000, 1, 1, 14, 0), Decimal('-0.49713370134285156'))
# (842, datetime.datetime(2000, 1, 1, 14, 1), Decimal('0.12171078636513159'))
# (843, datetime.datetime(2000, 1, 1, 14, 2), Decimal('0.5304081274740362'))
# (844, datetime.datetime(2000, 1, 1, 14, 3), Decimal('-0.6085451173230375'))
# (845, datetime.datetime(2000, 1, 1, 14, 4), Decimal('-0.8224054486072807'))
# (846, datetime.datetime(2000, 1, 1, 14, 5), Decimal('1.032232085055952'))
# (847, datetime.datetime(2000, 1, 1, 14, 6), Decimal('1.096402656208688'))
# (848, datetime.datetime(2000, 1, 1, 14, 7), Decimal('0.9311321901304049'))
# (849, datetime.datetime(2000, 1, 1, 14, 8), Decimal('1.4574941792629676'))
# (850, datetime.datetime(2000, 1, 1, 14, 9), Decimal('0.097781554664331'))
# (851, datetime.datetime(2000, 1, 1, 14, 10), Decimal('0.22055548142075115'))
# (852, datetime.datetime(2000, 1, 1, 14, 11), Decimal('-1.003716984992568'))
# (853, datetime.datetime(2000, 1, 1, 14, 12), Decimal('-0.09848571211309569'))
# (854, datetime.datetime(2000, 1, 1, 14, 13), Decimal('-2.226619186415781'))
# (855, datetime.datetime(2000, 1, 1, 14, 14), Decimal('1.3872296660749224'))
# (856, datetime.datetime(2000, 1, 1, 14, 15), Decimal('0.5552264809959805'))
# (857, datetime.datetime(2000, 1, 1, 14, 16), Decimal('-0.7082117725455893'))
# (858, datetime.datetime(2000, 1, 1, 14, 17), Decimal('0.2526798425958645'))
# (859, datetime.datetime(2000, 1, 1, 14, 18), Decimal('1.0953093062440027'))
# (860, datetime.datetime(2000, 1, 1, 14, 19), Decimal('0.6799162209109278'))
# (861, datetime.datetime(2000, 1, 1, 14, 20), Decimal('0.38042654771822004'))
# (862, datetime.datetime(2000, 1, 1, 14, 21), Decimal('-0.3022406563099146'))
# (863, datetime.datetime(2000, 1, 1, 14, 22), Decimal('1.2114762420108662'))
# (864, datetime.datetime(2000, 1, 1, 14, 23), Decimal('-0.66513121019072'))
# (865, datetime.datetime(2000, 1, 1, 14, 24), Decimal('-0.23830212995990907'))
# (866, datetime.datetime(2000, 1, 1, 14, 25), Decimal('-0.8277101900342105'))
# (867, datetime.datetime(2000, 1, 1, 14, 26), Decimal('1.5071650420751308'))
# (868, datetime.datetime(2000, 1, 1, 14, 27), Decimal('-0.1903188913713764'))
# (869, datetime.datetime(2000, 1, 1, 14, 28), Decimal('1.8102442574216704'))
# (870, datetime.datetime(2000, 1, 1, 14, 29), Decimal('0.937877975368575'))
# (871, datetime.datetime(2000, 1, 1, 14, 30), Decimal('0.34739605754302166'))
# (872, datetime.datetime(2000, 1, 1, 14, 31), Decimal('-0.7156504192837859'))
# (873, datetime.datetime(2000, 1, 1, 14, 32), Decimal('-0.5929444691979204'))
# (874, datetime.datetime(2000, 1, 1, 14, 33), Decimal('-0.9542451609468756'))
# (875, datetime.datetime(2000, 1, 1, 14, 34), Decimal('0.49058679516064596'))
# (876, datetime.datetime(2000, 1, 1, 14, 35), Decimal('0.10046809142350627'))
# (877, datetime.datetime(2000, 1, 1, 14, 36), Decimal('1.0598798356373407'))
# (878, datetime.datetime(2000, 1, 1, 14, 37), Decimal('0.7343722664714888'))
# (879, datetime.datetime(2000, 1, 1, 14, 38), Decimal('-0.6042066662669614'))
# (880, datetime.datetime(2000, 1, 1, 14, 39), Decimal('0.6046487214983425'))
# (881, datetime.datetime(2000, 1, 1, 14, 40), Decimal('-0.6317619226906476'))
# (882, datetime.datetime(2000, 1, 1, 14, 41), Decimal('0.17549857179869469'))
# (883, datetime.datetime(2000, 1, 1, 14, 42), Decimal('-1.592075748051157'))
# (884, datetime.datetime(2000, 1, 1, 14, 43), Decimal('0.6890521833274856'))
# (885, datetime.datetime(2000, 1, 1, 14, 44), Decimal('0.6719093643087365'))
# (886, datetime.datetime(2000, 1, 1, 14, 45), Decimal('-0.18861846889805434'))
# (887, datetime.datetime(2000, 1, 1, 14, 46), Decimal('-0.8336413466397185'))
# (888, datetime.datetime(2000, 1, 1, 14, 47), Decimal('1.0794097090182377'))
# (889, datetime.datetime(2000, 1, 1, 14, 48), Decimal('0.17523637451074076'))
# (890, datetime.datetime(2000, 1, 1, 14, 49), Decimal('0.13848461426221362'))
# (891, datetime.datetime(2000, 1, 1, 14, 50), Decimal('0.5035488940988698'))
# (892, datetime.datetime(2000, 1, 1, 14, 51), Decimal('-0.9543693202629204'))
# (893, datetime.datetime(2000, 1, 1, 14, 52), Decimal('1.6964181249892798'))
# (894, datetime.datetime(2000, 1, 1, 14, 53), Decimal('-0.1229094635546615'))
# (895, datetime.datetime(2000, 1, 1, 14, 54), Decimal('-0.5933264973450244'))
# (896, datetime.datetime(2000, 1, 1, 14, 55), Decimal('0.7485487611148156'))
# (897, datetime.datetime(2000, 1, 1, 14, 56), Decimal('0.8487724095051293'))
# (898, datetime.datetime(2000, 1, 1, 14, 57), Decimal('0.1341729026919182'))
# (899, datetime.datetime(2000, 1, 1, 14, 58), Decimal('1.1758178752035657'))
# (900, datetime.datetime(2000, 1, 1, 14, 59), Decimal('-0.32669749307278956'))
# (901, datetime.datetime(2000, 1, 1, 15, 0), Decimal('-1.4722405198814532'))
# (902, datetime.datetime(2000, 1, 1, 15, 1), Decimal('0.1555467152031518'))
# (903, datetime.datetime(2000, 1, 1, 15, 2), Decimal('0.8193533721914548'))
# (904, datetime.datetime(2000, 1, 1, 15, 3), Decimal('1.1619609498397176'))
# (905, datetime.datetime(2000, 1, 1, 15, 4), Decimal('-0.05873262855147923'))
# (906, datetime.datetime(2000, 1, 1, 15, 5), Decimal('-0.30979693383691215'))
# (907, datetime.datetime(2000, 1, 1, 15, 6), Decimal('1.0755305063831844'))
# (908, datetime.datetime(2000, 1, 1, 15, 7), Decimal('0.7607744373680981'))
# (909, datetime.datetime(2000, 1, 1, 15, 8), Decimal('1.4732501555617161'))
# (910, datetime.datetime(2000, 1, 1, 15, 9), Decimal('0.16347412342301385'))
# (911, datetime.datetime(2000, 1, 1, 15, 10), Decimal('-1.5965187861058563'))
# (912, datetime.datetime(2000, 1, 1, 15, 11), Decimal('1.1547334088546484'))
# (913, datetime.datetime(2000, 1, 1, 15, 12), Decimal('0.7999877875053142'))
# (914, datetime.datetime(2000, 1, 1, 15, 13), Decimal('-1.1848641952817038'))
# (915, datetime.datetime(2000, 1, 1, 15, 14), Decimal('-0.35959093618141563'))
# (916, datetime.datetime(2000, 1, 1, 15, 15), Decimal('-1.092933560899943'))
# (917, datetime.datetime(2000, 1, 1, 15, 16), Decimal('-1.0160084423217608'))
# (918, datetime.datetime(2000, 1, 1, 15, 17), Decimal('-0.06487157147934967'))
# (919, datetime.datetime(2000, 1, 1, 15, 18), Decimal('-1.7547694618964147'))
# (920, datetime.datetime(2000, 1, 1, 15, 19), Decimal('-0.5773445201043883'))
# (921, datetime.datetime(2000, 1, 1, 15, 20), Decimal('-0.24300591410838995'))
# (922, datetime.datetime(2000, 1, 1, 15, 21), Decimal('-0.236389612584371'))
# (923, datetime.datetime(2000, 1, 1, 15, 22), Decimal('0.05636173425049766'))
# (924, datetime.datetime(2000, 1, 1, 15, 23), Decimal('-0.20081361679033174'))
# (925, datetime.datetime(2000, 1, 1, 15, 24), Decimal('-0.28650794001699104'))
# (926, datetime.datetime(2000, 1, 1, 15, 25), Decimal('0.0523388051613825'))
# (927, datetime.datetime(2000, 1, 1, 15, 26), Decimal('-0.05023886598487408'))
# (928, datetime.datetime(2000, 1, 1, 15, 27), Decimal('0.7578521788363122'))
# (929, datetime.datetime(2000, 1, 1, 15, 28), Decimal('0.7577340926955887'))
# (930, datetime.datetime(2000, 1, 1, 15, 29), Decimal('0.23845315075940332'))
# (931, datetime.datetime(2000, 1, 1, 15, 30), Decimal('-0.397927889630636'))
# (932, datetime.datetime(2000, 1, 1, 15, 31), Decimal('-0.06059568162680872'))
# (933, datetime.datetime(2000, 1, 1, 15, 32), Decimal('-0.6806365089111741'))
# (934, datetime.datetime(2000, 1, 1, 15, 33), Decimal('-1.1404049166114532'))
# (935, datetime.datetime(2000, 1, 1, 15, 34), Decimal('-0.5615516161001131'))
# (936, datetime.datetime(2000, 1, 1, 15, 35), Decimal('0.5433610790950213'))
# (937, datetime.datetime(2000, 1, 1, 15, 36), Decimal('0.6320550005898735'))
# (938, datetime.datetime(2000, 1, 1, 15, 37), Decimal('0.051273599514136625'))
# (939, datetime.datetime(2000, 1, 1, 15, 38), Decimal('-1.759728649576825'))
# (940, datetime.datetime(2000, 1, 1, 15, 39), Decimal('-1.3807925484092567'))
# (941, datetime.datetime(2000, 1, 1, 15, 40), Decimal('-0.06519941638078536'))
# (942, datetime.datetime(2000, 1, 1, 15, 41), Decimal('0.5679061983192047'))
# (943, datetime.datetime(2000, 1, 1, 15, 42), Decimal('0.4884449793091423'))
# (944, datetime.datetime(2000, 1, 1, 15, 43), Decimal('0.40256412793738217'))
# (945, datetime.datetime(2000, 1, 1, 15, 44), Decimal('-0.04102879272151868'))
# (946, datetime.datetime(2000, 1, 1, 15, 45), Decimal('-0.5969487442106014'))
# (947, datetime.datetime(2000, 1, 1, 15, 46), Decimal('-0.06380060679336996'))
# (948, datetime.datetime(2000, 1, 1, 15, 47), Decimal('0.2682873293185309'))
# (949, datetime.datetime(2000, 1, 1, 15, 48), Decimal('0.3914357393517867'))
# (950, datetime.datetime(2000, 1, 1, 15, 49), Decimal('0.7560112759413494'))
# (951, datetime.datetime(2000, 1, 1, 15, 50), Decimal('0.3287669561536893'))
# (952, datetime.datetime(2000, 1, 1, 15, 51), Decimal('-2.4179829858863338'))
# (953, datetime.datetime(2000, 1, 1, 15, 52), Decimal('-0.36625576972443347'))
# (954, datetime.datetime(2000, 1, 1, 15, 53), Decimal('0.8167173443114373'))
# (955, datetime.datetime(2000, 1, 1, 15, 54), Decimal('-1.4907555929462182'))
# (956, datetime.datetime(2000, 1, 1, 15, 55), Decimal('0.17550024646320947'))
# (957, datetime.datetime(2000, 1, 1, 15, 56), Decimal('-1.41144194168883'))
# (958, datetime.datetime(2000, 1, 1, 15, 57), Decimal('-0.8004780265161741'))
# (959, datetime.datetime(2000, 1, 1, 15, 58), Decimal('-1.3931432405810582'))
# (960, datetime.datetime(2000, 1, 1, 15, 59), Decimal('-0.2795019377449692'))
# (961, datetime.datetime(2000, 1, 1, 16, 0), Decimal('-0.412722546024151'))
# (962, datetime.datetime(2000, 1, 1, 16, 1), Decimal('-0.2741873699047518'))
# (963, datetime.datetime(2000, 1, 1, 16, 2), Decimal('-1.0285737019795576'))
# (964, datetime.datetime(2000, 1, 1, 16, 3), Decimal('1.78458034298855'))
# (965, datetime.datetime(2000, 1, 1, 16, 4), Decimal('1.0867942414101408'))
# (966, datetime.datetime(2000, 1, 1, 16, 5), Decimal('-1.2058488128566844'))
# (967, datetime.datetime(2000, 1, 1, 16, 6), Decimal('0.7444754593360682'))
# (968, datetime.datetime(2000, 1, 1, 16, 7), Decimal('-0.3323619080120986'))
# (969, datetime.datetime(2000, 1, 1, 16, 8), Decimal('-0.6665910581950283'))
# (970, datetime.datetime(2000, 1, 1, 16, 9), Decimal('0.7717442560125998'))
# (971, datetime.datetime(2000, 1, 1, 16, 10), Decimal('1.4484400427318975'))
# (972, datetime.datetime(2000, 1, 1, 16, 11), Decimal('-0.5941220787931131'))
# (973, datetime.datetime(2000, 1, 1, 16, 12), Decimal('-1.4357916843716891'))
# (974, datetime.datetime(2000, 1, 1, 16, 13), Decimal('0.7875306047765115'))
# (975, datetime.datetime(2000, 1, 1, 16, 14), Decimal('-0.8179753742225246'))
# (976, datetime.datetime(2000, 1, 1, 16, 15), Decimal('0.5654728787292014'))
# (977, datetime.datetime(2000, 1, 1, 16, 16), Decimal('-0.3344105952603779'))
# (978, datetime.datetime(2000, 1, 1, 16, 17), Decimal('0.8846880542372345'))
# (979, datetime.datetime(2000, 1, 1, 16, 18), Decimal('1.3985572464423928'))
# (980, datetime.datetime(2000, 1, 1, 16, 19), Decimal('1.1087166104055488'))
# (981, datetime.datetime(2000, 1, 1, 16, 20), Decimal('0.060039629882883076'))
# (982, datetime.datetime(2000, 1, 1, 16, 21), Decimal('0.6434154742229182'))
# (983, datetime.datetime(2000, 1, 1, 16, 22), Decimal('0.036751144292282455'))
# (984, datetime.datetime(2000, 1, 1, 16, 23), Decimal('1.1055492829341864'))
# (985, datetime.datetime(2000, 1, 1, 16, 24), Decimal('-0.4354707903941973'))
# (986, datetime.datetime(2000, 1, 1, 16, 25), Decimal('-0.5604543427417474'))
# (987, datetime.datetime(2000, 1, 1, 16, 26), Decimal('-0.31394757155010405'))
# (988, datetime.datetime(2000, 1, 1, 16, 27), Decimal('0.9205408263306036'))
# (989, datetime.datetime(2000, 1, 1, 16, 28), Decimal('-1.5364212311957557'))
# (990, datetime.datetime(2000, 1, 1, 16, 29), Decimal('-1.227835115207505'))
# (991, datetime.datetime(2000, 1, 1, 16, 30), Decimal('1.3603474035837846'))
# (992, datetime.datetime(2000, 1, 1, 16, 31), Decimal('-0.3407559953627978'))
# (993, datetime.datetime(2000, 1, 1, 16, 32), Decimal('0.41233775122435923'))
# (994, datetime.datetime(2000, 1, 1, 16, 33), Decimal('-1.4339885916996213'))
# (995, datetime.datetime(2000, 1, 1, 16, 34), Decimal('-0.4216683437696531'))
# (996, datetime.datetime(2000, 1, 1, 16, 35), Decimal('1.3525231529571933'))
# (997, datetime.datetime(2000, 1, 1, 16, 36), Decimal('-1.1336376828984336'))
# (998, datetime.datetime(2000, 1, 1, 16, 37), Decimal('1.1435662052959854'))
# (999, datetime.datetime(2000, 1, 1, 16, 38), Decimal('0.41519872767076715'))
# (1000, datetime.datetime(2000, 1, 1, 16, 39), Decimal('-0.1891098458966201'))
